# %%
import tweepy
  
# assign the values accordingly
consumer_key = "2O2y7BDZLFdtlmBcDdENZoJ96"
consumer_secret = "c5q5p1d4gLsyU6o3kmccMJter2kRAlIQwDly6u3Z2qal2Qp6t1"
access_token = "1492543557495922694-mkpl4Cz1gJIexoICRAeblNCvbYNXJ5"
access_token_secret = "oMOjHisdf6htyy1KMYG6Df7zXvGtpUIa4XkuRaoUmtubi"

# authorization of consumer key and consumer secret
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# set access to user's access key and access secret 
auth.set_access_token(access_token, access_token_secret)

# calling the api 
api = tweepy.API(auth, wait_on_rate_limit=True)

rams_userlist=['B_ALLO_14','LoganBruss','king_calais','rogerc0331','TCarter615','Marquisecope_44','Caesar_Austin',
'camerondicker','Elijah30Garcia','jakegervase10','haleyboy10','robhavenstein78','thrilll_32','MHoecht96',
'jakehumms','Up_Like7','KendrickDemari','Duron_lowe_1','mccutcheonlance','TheMcvea','PerezLuisQB','jamal80p',
'_powellbp4','ajrose_10','C_JJ_Rozeboom','jacksnyder55','matt_stafford9','BraydenThomas21','_popcool','Bxnwhitley',
'PircherMax','johnwolford_9','Garrettchris52','Bigaj77','AshawnRobinson','Itsbhop89','jnoteboom70','justinhollins_',
'bobbyiii5','jalenramsey','ernestjones50','ErnieBIV','scootaa11','quentin_lake','j_fuller4','VanJefferson12',
'tutuatwell','DarrellH8','Kyrenwilliams23','TremayneAnchrum','thereal_cam3','russ_yeast03','Leonard90Flo',
'troyreeder9','_rayshawnnn_','Dhardy44','JacobHarris87','AllenRobinson','nickmscotty','trapp07','CBrew_97',
'One4_era','BobbyEvans44','TDN_Perk','AaronDonald97','GregGaines99','jakefunk34','Ty_Higs19','_Real24_','CooperKupp',
'MGtweetymonster','TiTaniumT98','TheKspecial_','dedwards','obj','davidlongjr','ARCURIaj85','RileyTDixon92',
'BennySkow','Bwagz']
bengals_userlist=['Keem78theGreat','CalAdomitis','brandon21allen','MrToledo01','EliApple','ChidobeAwuzie',
'JoeBach35','mb_boiler21','jlbiii3','Vonn','boutdat_23','Ben_Brown55','jake_browning','JoeyB','AlexCappa',
'Jackthejiant','_Zachattacks','Real10jayy__','DChrisman91','Devin_Cochran57','Lael_Collins','AbuDaramySwaray',
'NiqueSavo','__iamjalen','AkeemDavis16','banksera82','Kidnplay_abc123','_Slimm7','VandyGeorge','jgunter94',
'jgunter94','ClarkHarris46','JHeiligh','_T_Hen','c9inee','teehiggins5','BJHill5','daxhill5','hilldeontrey',
'MikeHilton_28','Delontehood','Sam_Hubbard_','khuber10','Wyatt_Bert','haydenrhurst','trenton_4','x_jay6',
'shermarijones','khalid_kareem53','_teddy_k','kwamie_lassiter','McPherson_Evan','Joe_MainMixon','Thekidstan',
'Thaddeusmoss','IGOHARD65','joseph_ossai','jacques_patrick','samajp32','dp_TheTruth','GermainePratt7','ThePrince_59',
'_KPryor3','Bookie_44','Djread98','justinrigg83','cameron_sample','drewcal','Tegray_Scales8','B1GSmoove','jsore13',
'nspence94','Trent5Taylor','CamTaylorBritt_','Michael31Thomas','Michael31Thomas','t_tisdale22','JoshTupouCU',
'c_volson','wells_16','wilcox_mitchell','PookaWilliamsJr','JonahGWilliams','TrayveonW','ItsBWilson_','ljw21']

d1={}
d2={}
d3={}
for i in rams_userlist:
    for j in bengals_userlist:
        is_following = api.get_friendship(source_screen_name=i, target_screen_name=j)
        d1["following"]=is_following[0].following
        d1["Followed by"]=is_following[0].followed_by
        d2[j]=d1
    d3[i]=d2
# Out:
# Rate limit reached. Sleeping for: 693

# %%
no_rams_foll_beng=0
no_rams_followedby_beng=0
for i in rams_userlist[0:10]:
    for j in bengals_userlist[0:10]:
        if d3[i][j]['following']==False:
            continue
        else:
            no_rams_foll_beng+=1
        if d3[i][j]['Followed by']==False:
            continue
        else:
            no_rams_followedby_beng+=1
print(no_rams_foll_beng)
print(no_rams_followedby_beng)
# Out:
# 0
# 0

# %%
d3
# Out:
# {'B_ALLO_14': {'Keem78theGreat': {'following': False, 'Followed by': False},
#   'CalAdomitis': {'following': False, 'Followed by': False},
#   'brandon21allen': {'following': False, 'Followed by': False},
#   'MrToledo01': {'following': False, 'Followed by': False},
#   'EliApple': {'following': False, 'Followed by': False},
#   'ChidobeAwuzie': {'following': False, 'Followed by': False},
#   'JoeBach35': {'following': False, 'Followed by': False},
#   'mb_boiler21': {'following': False, 'Followed by': False},
#   'jlbiii3': {'following': False, 'Followed by': False},
#   'Vonn': {'following': False, 'Followed by': False}},
#  'LoganBruss': {'Keem78theGreat': {'following': False, 'Followed by': False},
#   'CalAdomitis': {'following': False, 'Followed by': False},
#   'brandon21allen': {'following': False, 'Followed by': False},
#   'MrToledo01': {'following': False, 'Followed by': False},
#   'EliApple': {'following': False, 'Followed by': False},
# ...

# %%
import tweepy
  
# assign the values accordingly
consumer_key = "2O2y7BDZLFdtlmBcDdENZoJ96"
consumer_secret = "c5q5p1d4gLsyU6o3kmccMJter2kRAlIQwDly6u3Z2qal2Qp6t1"
access_token = "1492543557495922694-mkpl4Cz1gJIexoICRAeblNCvbYNXJ5"
access_token_secret = "oMOjHisdf6htyy1KMYG6Df7zXvGtpUIa4XkuRaoUmtubi"
  
# authorization of consumer key and consumer secret
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# set access to user's access key and access secret 
auth.set_access_token(access_token, access_token_secret)

# calling the api 
api = tweepy.API(auth, wait_on_rate_limit=True)
rams_userlist=['B_ALLO_14','LoganBruss','king_calais','rogerc0331','TCarter615','Marquisecope_44','Caesar_Austin',
'camerondicker','Elijah30Garcia','jakegervase10','haleyboy10','robhavenstein78','thrilll_32','MHoecht96',
'jakehumms','Up_Like7','KendrickDemari','Duron_lowe_1','mccutcheonlance','TheMcvea','PerezLuisQB','jamal80p',
'_powellbp4','ajrose_10','C_JJ_Rozeboom','jacksnyder55','matt_stafford9','BraydenThomas21','_popcool','Bxnwhitley',
'PircherMax','johnwolford_9','Garrettchris52','Bigaj77','AshawnRobinson','Itsbhop89','jnoteboom70','justinhollins_',
'bobbyiii5','jalenramsey','ernestjones50','ErnieBIV','scootaa11','quentin_lake','j_fuller4','VanJefferson12',
'tutuatwell','DarrellH8','Kyrenwilliams23','TremayneAnchrum','thereal_cam3','russ_yeast03','Leonard90Flo',
'troyreeder9','_rayshawnnn_','Dhardy44','JacobHarris87','AllenRobinson','nickmscotty','trapp07','CBrew_97',
'One4_era','BobbyEvans44','TDN_Perk','AaronDonald97','GregGaines99','jakefunk34','Ty_Higs19','_Real24_','CooperKupp',
'MGtweetymonster','TiTaniumT98','TheKspecial_','dedwards','obj','davidlongjr','ARCURIaj85','RileyTDixon92',
'BennySkow','Bwagz']
bengals_userlist=['Keem78theGreat','CalAdomitis','brandon21allen','MrToledo01','EliApple','ChidobeAwuzie',
'JoeBach35','mb_boiler21','jlbiii3','Vonn','boutdat_23','Ben_Brown55','jake_browning','JoeyB','AlexCappa',
'Jackthejiant','_Zachattacks','Real10jayy__','DChrisman91','Devin_Cochran57','Lael_Collins','AbuDaramySwaray',
'NiqueSavo','__iamjalen','AkeemDavis16','banksera82','Kidnplay_abc123','_Slimm7','VandyGeorge','jgunter94',
'jgunter94','ClarkHarris46','JHeiligh','_T_Hen','c9inee','teehiggins5','BJHill5','daxhill5','hilldeontrey',
'MikeHilton_28','Delontehood','Sam_Hubbard_','khuber10','Wyatt_Bert','haydenrhurst','trenton_4','x_jay6',
'shermarijones','khalid_kareem53','_teddy_k','kwamie_lassiter','McPherson_Evan','Joe_MainMixon','Thekidstan',
'Thaddeusmoss','IGOHARD65','joseph_ossai','jacques_patrick','samajp32','dp_TheTruth','GermainePratt7','ThePrince_59',
'_KPryor3','Bookie_44','Djread98','justinrigg83','cameron_sample','drewcal','Tegray_Scales8','B1GSmoove','jsore13',
'nspence94','Trent5Taylor','CamTaylorBritt_','Michael31Thomas','Michael31Thomas','t_tisdale22','JoshTupouCU',
'c_volson','wells_16','wilcox_mitchell','PookaWilliamsJr','JonahGWilliams','TrayveonW','ItsBWilson_','ljw21']

# %%
rams_userlist1=['B_ALLO_14','LoganBruss','king_calais','rogerc0331','TCarter615','Marquisecope_44','Caesar_Austin',
'camerondicker','Elijah30Garcia','jakegervase10']
bengals_userlist1=['Keem78theGreat','CalAdomitis','brandon21allen','MrToledo01','EliApple','ChidobeAwuzie',
'JoeBach35','mb_boiler21','jlbiii3','Vonn']

d1={}
d2={}
d3={}
for i in rams_userlist1:
    for j in bengals_userlist1:
        is_following = api.get_friendship(source_screen_name=i, target_screen_name=j)
        d1['Following']=is_following[0].following
        d1['Followed_by']=is_following[0].followed_by
        d2[j]=d1
    d3[i]=d2

# %%
rams_foll_beng1=0
rams_followedby_beng1=0
for i in rams_userlist1:
    for j in bengals_userlist1:
        if d3[i][j]['Following']==False:
            continue
        else:
            rams_foll_beng1+=1
        if d3[i][j]['Followed_by']==False:
            continue
        else:
            rams_followedby_beng1+=1
print(rams_foll_beng1)
print(rams_followedby_beng1)
# Out:
# 0
# 0

# %%
rams_userlist2=['B_ALLO_14','LoganBruss','king_calais','rogerc0331','TCarter615','Marquisecope_44','Caesar_Austin',
'camerondicker','Elijah30Garcia','jakegervase10']
bengals_userlist2=['boutdat_23','Ben_Brown55','jake_browning','JoeyB','AlexCappa','Jackthejiant','_Zachattacks',
'Real10jayy__','DChrisman91','Devin_Cochran57']

d4={}
d5={}
d6={}
for i in rams_userlist[0:9]:
    for j in bengals_userlist[10:19]:
        is_following = api.get_friendship(source_screen_name=i, target_screen_name=j)
        d4['Following']=is_following[0].following
        d4['Followed_by']=is_following[0].followed_by
        d5[j]=d4
    d6[i]=d5
# Out:
# Rate limit reached. Sleeping for: 555

# %%
d6
# Out:
# {'B_ALLO_14': {'boutdat_23': {'Following': False, 'Followed_by': False},
#   'Ben_Brown55': {'Following': False, 'Followed_by': False},
#   'jake_browning': {'Following': False, 'Followed_by': False},
#   'JoeyB': {'Following': False, 'Followed_by': False},
#   'AlexCappa': {'Following': False, 'Followed_by': False},
#   'Jackthejiant': {'Following': False, 'Followed_by': False},
#   '_Zachattacks': {'Following': False, 'Followed_by': False},
#   'Real10jayy__': {'Following': False, 'Followed_by': False},
#   'DChrisman91': {'Following': False, 'Followed_by': False}},
#  'LoganBruss': {'boutdat_23': {'Following': False, 'Followed_by': False},
#   'Ben_Brown55': {'Following': False, 'Followed_by': False},
#   'jake_browning': {'Following': False, 'Followed_by': False},
#   'JoeyB': {'Following': False, 'Followed_by': False},
#   'AlexCappa': {'Following': False, 'Followed_by': False},
#   'Jackthejiant': {'Following': False, 'Followed_by': False},
# ...

# %%
rams_foll_beng2=0
rams_followedby_beng2=0
for i in rams_userlist[0:9]:
    for j in bengals_userlist[10:19]:
        if d3[i][j]['Following']==False:
            continue
        else:
            rams_foll_beng1+=1
        if d3[i][j]['Followed_by']==False:
            continue
        else:
            rams_followedby_beng1+=1
print(rams_foll_beng2)
print(rams_followedby_beng2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28296\348615864.py in <module>
# ----> 1 api.rate_limit
#
# NameError: name 'api' is not defined
