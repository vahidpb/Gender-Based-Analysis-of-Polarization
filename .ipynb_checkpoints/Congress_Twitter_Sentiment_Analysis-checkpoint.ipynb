# %% [markdown]
# # Extracting the last 100 tweets of congress members

# %% [markdown]
# # Importing the required packages

# %%
import tweepy
import pandas as pd
from nltk.corpus import stopwords
import string
import re
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vahidpb\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vahidpb\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Pulling last 100 tweets of congress memebers

# %%
tweet_data=pd.read_excel(r'C:\Users\vahidpb\Documents\GitHub\Gender-Based-Analysis-of-Polarization\PoliticianTwitterInput.xlsx')
# Creating a list of all stop words
stop_words=stopwords.words('English')
# Creating a list of all punctuation
temp=set(string.punctuation)
punctuation=[]
for i in temp:
    punctuation.append(i)
consumer_key = "OCpoOVeSDgFAjsdh31D2vn3HE"
consumer_secret = "3hFAY6up1dhDxoQbgxNyYoVABhatix7qsYJxwWpyF3G65GQVC4"
access_token = "1492543557495922694-GY4RxcQAzpNfZW38XyqJppRe7HsAbM"
access_token_secret = "ToaW7vEPhhE953hfRRKxYnVqRvMIa286dCEvObC50l9Wg"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
user_list=[]
for i in tweet_data.index:
    user_list.append(tweet_data['Twitter_Handle'][i])
#print(user_list)
tweets_df=pd.DataFrame()
for j in user_list:
    username=j
    count = 100
    try: 
    # Creation of query method using parameters
        tweets = tweepy.Cursor(api.user_timeline,id=username,include_rts=False).items(count)
     # Pulling information from tweets iterable object
        tweets_list = [[tweet.text] for tweet in tweets]
        if (len(tweets_list)==100):
     # Creation of dataframe from tweets list
     # Add or remove columns as you remove tweet information
            tweets_df.loc[:,username]=tweets_list 
    except BaseException as e:
        print(f'{username}')
        continue
tweets_df.to_csv("congress_tweets.csv")
# Out:
# MarshaBlackburn
# RepGarbino
# RepHastingsFL
# RepJoeKennedy
# senlujan
# RepManning
# RepMrvan
# RepTomReed
# RepTomRice
# RepChrisSmith
# JeffVanDrew
# VanHollenForMD
# RepMichaelWaltz
# RepBradWenstrup

# %% [markdown]
# # Data pre-processing

# %%
congress_tweets=pd.read_csv(r'C:\Users\vahidpb\Documents\GitHub\Gender-Based-Analysis-of-Polarization\congress_tweets.csv')
for i in user_list:
    username=i
    try:
        # Converting whole text into lower case to maintain uniformity
        congress_tweets[i]=congress_tweets[i].str.lower()
        # Eliminating the punctuations
        congress_tweets[i]=congress_tweets[i].str.replace('[^\w\s]', '') 
        # Eliminating the numbers
        congress_tweets[i]=congress_tweets[i].str.replace('\d', '')
        # Eliminating the stop words
        congress_tweets[i]=congress_tweets[i].apply(lambda x: " ".join(x for x in str(x).split() if x not in stop_words))
        # Converting the text column as a single string for wordcloud
        reviews=str(congress_tweets[i])
        # Removing the URLS from the tweet string
        reviews_new=re.sub(r'http\S+', ' ', reviews)
        # Deleting everything which is not characters
        reviews_new = re.sub(r'[^a-z A-Z]', ' ',reviews_new)
        # Stripping extra spaces in the text
        reviews_new= re.sub(r' +', ' ', reviews_new)
        # Creating the custom stopwords
        customStopwords = stop_words
    except Exception as e:
        print(f'{i}')
# Out:
# MarshaBlackburn
# Nothing verified
# RepGarbino
# RepHastingsFL
# RepJoeKennedy
# nan
# nan
# senlujan
# RepManning
# RepMarshall
# nan
# nan
# RepMrvan
# Jay Obernolte
# RepTomReed
# RepTomRice
# GuamCongressman
# 0   met ndsus new president david cook today look ...
# 1   years members usarmy bravely defended nation g...
# 2   happy flag day proud redwhite blue httpstcoatb...
# 3   recently welcomed premier saskatchewan premier...
# 4   north dakotas nurses best nation thank susan s...
# ..                                                ...
# 95                    httpstcoxxsdetm httpstcotddhugg
# 96       loodog closeup_dc best part job hope enjoyed
# 97  north dakotas students back capitol hill smart...
# 98  always fun catch team bushelpowered north dako...
# 99  good discussion nd rural water today projects ...
#
#                                          RepArrington  \
# 0   invited secretary amp president biden visit we...
# 1   week treasury secretary janet yellen testified...
# 2   national average gas hits first time democrats...
# 3   gun control laws passed house place states hig...
# 4   love freedom enes kanter freedom patriot man g...
# ..                                                ...
# 95  fought secure hypersonic weapons long range bo...
# 96  sad hear news passing young character passiona...
# 97  today president volodymyr zelenskyy addressed ...
# 98  portstoplains interstate coming west texas gam...
# 99  consistent bidens timid response thus far legi...
#
#                                        RepAuchincloss  ...  \
# 0   deal save lives grants credence gops deranged ...  ...
# 1   debating gun violence gop week holding massach...  ...
# 2   horrific shootings buffalo uvalde painful remi...  ...
# 3   boston bds amp mapping project tapping millenn...  ...
# 4   tune msnbc pm et watch chat next steps gun saf...  ...
# ..                                                ...  ...
# 95  afternoon joined neighbors attleboro stand sol...  ...
# 96  ever wonder like member congress sotu httpstco...  ...
# 97  yesterday opposed graves amendment could slow ...  ...
# 98  offshore wind energy help us realize emissions...  ...
# 99  wh released national covid preparedness plan r...  ...
#
#                                          RepRWilliams  \
# 0   years ago today republican baseball team becam...
# 1              happy birthday usarmy httpstcooseobkvc
# 2   since old glory beacon hope freedom entire wor...
# 3   biden administration continues wage war americ...
# 4   someone experienced sort political violence fi...
# ..                                                ...
# 95  biden administrations failed policies led reco...
# 96  honored receive accausas coolest congress awar...
# 97  enjoyed visit danielle ralphdrollinger continu...
# 98  us potential lead exporter oil natural gas ord...
# 99  honored witness president zelenskyys historic ...
#
#                                             RepWilson  \
# 0   mantra always jobs jobs jobs proud bring home ...
# 1   daca opened opportunities enabled generation y...
# 2   congratulations future commissioner mickystein...
# 3   today shared story witnessed time amp time edu...
# 4   care us fear lives safety light increased thre...
# ..                                                ...
# 95  families depend baby formula feed youngest one...
# 96  pleasure join local leaders young men rolemode...
# 97  congratulations cityofmiagarden years communit...
# 98  nation bears heavy burden one million american...
# 99  frontline tsa workers help keep skies safe pos...
#
#                                          RepJoeWilson  \
# 0   cochair friends belgium caucus grateful join b...
# 1   improving care military families special needs...
# 2   grateful introduced nationalrighttowork act in...
# 3   dissidents authoritarian regimes social media ...
# 4   th day putins murderous invasion sovereign ukr...
# ..                                                ...
# 95  irans ballistic missile program proceeding ahe...
# 96  pleasure convene republicanstudy national secu...
# 97  visit turkey valued member nato nato supports ...
# 98  cochair caucus usturkey relations turkish amer...
# 99  bidens haphazard withdraw us forces afghanista...
#
#                                            RobWittman  \
# 0   happy th birthday usarmy thank men women us ar...
# 1   inflation tax americans must rein washingtons ...
# 2   inflation skyrocketed highest spike years gall...
# 3   honor serving jimlangevin thank many years lea...
# 4   us must defense budget allows us compete adver...
# ..                                                ...
# 95  today celebrate presidents throughout history ...
# 96  thrilled advancement chesapeake bay seee act t...
# 97  cyberattacks critical infrastructure threaten ...
# 98  ill joining seanspicer amp lyndsaymkeith eveni...
# 99  inflation surged past year year high inflation...
#
#                                       rep_stevewomack  \
# 0   fort smith supporting sound freedom heard arou...
# 1   always ready always congratulations brigadier ...
# 2   ar dc thanks gabrielle russell van buren jayde...
# 3   years american soldiers forefront defense they...
# 4   american flag unwavering symbol liberty honor ...
# ..                                                ...
# 95  aracademyspotlight meet daniel huntsman bella ...
# 96  read shannon smith winner ars congressional ar...
# 97  shannons composition caught eyes judges congra...
# 98  asked inspires said recent medal honor recipie...
# 99  hell soon commission usairforce first statione...
#
#                                              RonWyden  \
# 0                    read proposal httpstcoitymtdbjdc
# 1   america facing youth mental health crisis toda...
# 2   accident republicans efforts outlaw abortion c...
# 3   americans paying nose gas pump big oil raking ...
# 4   sounded alarm website allowed law enforcement ...
# ..                                                ...
# 95  thanks secbecerra meeting today portland lines...
# 96  oil companies must held accountable profiteeri...
# 97  lets clear headed republicans going try put cr...
# 98  everybody oregon anywhere must able practice r...
# 99  passing fourth amendment sale act would make h...
#
#                                        RepJohnYarmuth  \
# 0   todays daca anniversary reminder tremendous pa...
# 1   right honor nations flag native spirit day wis...
# 2     republicans would kill majority httpstcopisngst
# 3   thrilled announced another vital federal inves...
# 4   senate hasnt taken meaningful action address g...
# ..                                                ...
# 95  keturahherron tireless advocate fairness justi...
# 96  honored receive legacy award scky_ dear friend...
# 97  charles youngs life story remarkable testament...
# 98  predictable consequence society guns important...
# 99  relieved learn craig team unharmed todays shoo...
#
#                                           repdonyoung  \
# 0   following ceremony entire program rebroadcast ...
# 1   coverage starts ak timeam et tuesday march th ...
# 2   live coverage allow alaskans around nation wat...
# 3   tomorrow tuesday march th cspan covering congr...
# 4   event open public encourage anyone wants honor...
# ..                                                ...
# 95  met alaska chapter pawsph steadfast advocates ...
# 96  weekend attended annual hope auction raises fu...
# 97  want thank good friend repgwenmoore joining co...
# 98  wideranging discussion topics resource develop...
# 99  asrc_ak major contributor aks economy amp impo...
#
#                                          SenToddYoung  \
# 0   urgent national security imperative get bipart...
# 1   new bipartisan emergencysavingsact introduced ...
# 2   israel continues position key player global en...
# 3   icymi yesterday joined wowofortwayne discuss y...
# 4   good news bipartisan legislation cosponsored a...
# ..                                                ...
# 95  must support ukrainian people repel russia als...
# 96  like hoosiers continue inspired heroic resista...
# 97  spoke todays first conference committee meetin...
# 98  wish could attended inperson great join annual...
# 99  biden administrations energy policies hurting ...
#
#                                          RepLeeZeldin
# 0   kidding govkathyhochul hochul unilaterally wit...
# 1   flag must always stand freedom happy flagday h...
# 2   serving usarmy past years alongside nations fi...
# 3        covid vaccine mandates anyone level anything
# 4   average gas price hit per gallon unaffordable ...
# ..                                                ...
# 95  apparently students joseph r biden school poli...
# 96  court appeals ny dropped dropped sledgehammer ...
# 97  republicans take house january one first subpo...
# 98  public service entirely serving public served ...
# 99  remote learning substitute person education yo...
#
# [100 rows x 518 columns]
