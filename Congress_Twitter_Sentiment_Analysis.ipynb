# %%
import tweepy
import pandas as pd
tweet_data=pd.read_excel(r'C:\Users\vahidpb\Downloads\PoliticianTwitterInput.xlsx')
consumer_key = "OCpoOVeSDgFAjsdh31D2vn3HE"
consumer_secret = "3hFAY6up1dhDxoQbgxNyYoVABhatix7qsYJxwWpyF3G65GQVC4"
access_token = "1492543557495922694-GY4RxcQAzpNfZW38XyqJppRe7HsAbM"
access_token_secret = "ToaW7vEPhhE953hfRRKxYnVqRvMIa286dCEvObC50l9Wg"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
user_list=[]
for i in tweet_data.index:
    user_list.append(tweet_data['Twitter_Handle'][i])
#print(user_list)

n=0
tweets_df=pd.DataFrame()
for j in user_list:
    username=j
#username = user_list[n]
    count = 100
    try: 
    # Creation of query method using parameters
        tweets = tweepy.Cursor(api.user_timeline,id=username).items(count)
     # Pulling information from tweets iterable object
        tweets_list = [[tweet.text] for tweet in tweets]
        if len(tweets_list)==100:
     # Creation of dataframe from tweets list
     # Add or remove columns as you remove tweet information
            tweets_df.loc[:,username]=tweets_list
        #tweets_df['username']=user_list
    except BaseException as e:

        print(f'{username}')
        continue
# Out:
# RepAndyBarr
# RepGarbino

# %%
tweets_df
# Out:
#                                              RepAdams  \
# 0   [RT @SecCardona: No matter who you love, how y...
# 1   [RT @RepDwightEvans: 1/ #OTD 59 years ago, the...
# 2   [I didn't ask for a pardon.\n\nBut a certain P...
# 3   [Your daily reminder that instead of saying so...
# 4   [I’m proud to work with my Congressional colle...
# ..                                                ...
# 95  [RT @EdLaborCmte: .@RepAdams is speaking on th...
# 96  [RT @UNCF: Our team at UNCF is dedicated to th...
# 97  [This week marks 68 years since the landmark B...
# 98  [My love and support goes out to all of our LG...
# 99  [North Carolina, today is Election Day! The pe...
#
#                                       Robert_Aderholt  \
# 0   When are Democrats going to hold a primetime h...
# 1   Today I joined Americans United for Life in ca...
# 2   Democrats seem to have little concern about th...
# 3   The economy is headed down a dark path and the...
# 4   Today we honor the brave men who put their liv...
# ..                                                ...
# 95  This invasion is a brutal effort by Putin to s...
# 96   I’m sending my prayers to the people of Ukraine.
# 97  I think the AHSAA does need to further clarify...
# 98  The unsecured southern border isn’t just an is...
# 99  RT @RepGallagher: Rep. Gallagher led more than...
#
#                                        RepPeteAguilar  \
# 0   RT @JoyAnnReid: Tonight on @thereidout we’ll f...
# 1   Tonight, the @January6thCmte will present the ...
# 2   Tonight, the @January6thCmte will begin presen...
# 3   RT @JDBalartMSNBC: 10am ET / 7am PT, @jdbalart...
# 4   Today the House will pass the #ProtectingOurKi...
# ..                                                ...
# 95        RT @HouseDemocrats: https://t.co/xZr5VMcyZw
# 96  Our government needs to work for working famil...
# 97  These resources go directly to projects that w...
# 98  RT @rosadelauro: Today is a historic day. @Hou...
# 99  I was happy to meet with Inland Action today a...
#
#                                          RepRickAllen  \
# 0   Thank you to @AUG_University Athletic Director...
# 1   🚨@BLS_gov now reports annual inflation has hit...
# 2   The @RepublicanStudy Committee has introduced ...
# 3   Tonight, I voted against House Democrats’ part...
# 4   Please join me in congratulating these five GA...
# ..                                                ...
# 95  Energy security is national security—and we mu...
# 96  Thank you @GAChamber for joining the long list...
# 97  Big Labor is pushing for changes to the defini...
# 98  We've seen the disastrous results from the ABC...
# 99  Employees should never have their privacy at r...
#
#                                        RepColinAllred  \
# 0   As the son of a Dallas public school teacher, ...
# 1   The #January6th hearing showed that Trump was ...
# 2   Teachers know their classrooms best and as the...
# 3   In the face of unspeakable violence on #Januar...
# 4   #OTD 59 years ago, the Equal Pay Act was signe...
# ..                                                ...
# 95  With technological advances in medicine and th...
# 96  This formula shortage will take a whole govern...
# 97  No parent should have to worry about how they ...
# 98  Addressing this crisis quickly will take every...
# 99  This has bipartisan support and it can, and sh...
#
#                                         MarkAmodeiNV2  \
# 0   It was a pleasure meeting with students from V...
# 1   My statement on House Democrats' gun control a...
# 2   RT @NeomaJardon: Hundreds of Mayors from acros...
# 3   In hopes of addressing the driver shortage, I’...
# 4   I met with representatives from the Nevada Pet...
# ..                                                ...
# 95  Incredibly proud of everything the Nevada Alli...
# 96  It’s an honor to receive the Friend of the Far...
# 97  Today, I voted against House Democrats’ unprec...
# 98  Recognizing the more than 200 members of the @...
# 99  My full statement on today’s impeachment vote:...
#
#                                        RepArmstrongND  \
# 0   Thank you to Pam Gulleson and Megan Houn with ...
# 1                             https://t.co/U6zDidz4rA
# 2   Find my full statement on my vote against Demo...
# 3   RT @GOPLeader: Democrats are using January 6 t...
# 4   RT @senrobportman: There is growing momentum f...
# ..                                                ...
# 95  RT @KFYRTV: Dickinson Police Department is dig...
# 96  Chag Sameach to Jews across North Dakota obser...
# 97  RT @JimKVRR: Due to severe weather, North Dako...
# 98  The @ndtaxdepartment already extended the stat...
# 99  Today, @SenJohnHoeven, @SenKevinCramer, and I ...
#
#                                          RepArrington  \
# 0   and invited the Secretary &amp; President Bide...
# 1   This week, Treasury Secretary Janet Yellen tes...
# 2   National average for gas hits $5 for first tim...
# 3   The very gun control laws that were passed out...
# 4   I love Freedom!\nEnes Kanter Freedom is a patr...
# ..                                                ...
# 95  As food prices climb, it is critical that this...
# 96  Another backward Biden policy. He is implement...
# 97  Ending Title 42 in the middle of the most seri...
# 98  How to lose a country in 10 years:\n— Cripple ...
# 99  With all due respect, Mr. President, we don’t ...
#
#                                        RepAuchincloss  \
# 0   After debating gun violence with the GOP all w...
# 1   The horrific shootings in Buffalo and Uvalde a...
# 2   RT @DemMaj4Israel: Thank you, @RepAuchincloss,...
# 3   RT @AIPAC: Thank you @RepAuchincloss for your ...
# 4   RT @J_Insider: .@RepAuchincloss denounced the ...
# ..                                                ...
# 95  Thank you to everyone who came out in Newton t...
# 96  RT @TheSunChronicle: U.S. Rep Jake Auchincloss...
# 97  RT @ManetCommunity: Thank you @RepAuchincloss ...
# 98  Today, I visited Manet Community Health Center...
# 99  RT @SharmanTV: "We should take more. We're a n...
#
#                                          RepCindyAxne  ...  \
# 0   This week, nearly 30 @soiowa athletes from #IA...  ...
# 1   The financial burdens Iowans are facing right ...  ...
# 2   Glad to see projects made possible by the bipa...  ...
# 3   I had a great time participating in the Americ...  ...
# 4   As families continue to feel the crushing weig...  ...
# ..                                                ...  ...
# 95  Medical debt is less predictive for credit rep...  ...
# 96  Honored to join the @ASPCA's Week of Action on...  ...
# 97  Congratulations to the Stilwell Junior High Sc...  ...
# 98  WATCH: During yesterday's @HouseAgDems hearing...  ...
# 99  Grateful for the opportunity to participate in...  ...
#
#                                          RepSamGraves  \
# 0   Gas was $2.39 when President Biden took office...
# 1   The average price for a gallon of gas in Ameri...
# 2   For years, I’ve talked about the importance of...
# 3   Far too many rural hospitals are on the brink ...
# 4   It’s critical to make sure the Corps does not ...
# ..                                                ...
# 95  That’s why I introduced a Congressional Review...
# 96  CMS has suspended enforcement of the vaccine m...
# 97  If an 18 year-old can drive a semi-truck in a ...
# 98  FEMA needs fixing. We’re making some great bip...
# 99  We shouldn’t rely on Russia and OPEC for our o...
#
#                                            RepAlGreen  \
# 0   **Join Me Live Today at 11:10am CT/ 12:10pm ET...
# 1   RT @townsquaretalk: #ICYMI: Thanks Congressman...
# 2   Democrats' gun control efforts are NOT meaning...
# 3   RT @townsquaretalk: June 6, 2020 #GeorgeFloyd ...
# 4   🚨 ATTENTION 🚨\n\nCatch me TODAY on @BloombergT...
# ..                                                ...
# 95  Speaking soon, tune in! https://t.co/HBLivrYK9...
# 96  It was an honor to join President Biden today ...
# 97  #ICYMI on @MSNBC with @AlexWitt: My response t...
# 98  This morning @FSCDems are holding a hearing to...
# 99  Catch me LIVE today on @MSNBC with  @AlexWitt ...
#
#                                          RepMarkGreen  \
# 0   #ICYMI🎙\n\nDemocrat control = pure chaos. \n\n...
# 1   This doesn’t look very “transitory” to me. Whi...
# 2   🚨👉1982. That’s the last time inflation was thi...
# 3   My Western Hemisphere Nearshoring Act addresse...
# 4   Rilee Kat Vest is a role model for all young l...
# ..                                                ...
# 95  #ICYMI → My Baby Formula Emergency Act lifts t...
# 96  Happy Week of the Eagles, @101stAASLTDIV @Fort...
# 97  An unborn baby is a life worth protecting. An ...
# 98  Saying I’m a terrorist after going to combat t...
# 99  This devastating crisis deserves President Bid...
#
#                                                RepMTG  \
# 0   This is what Americans think about Jan 6th Hol...
# 1   This hurts the poor, but not the fools running...
# 2   .@TuckerCarlson reports the truth about issues...
# 3   RT @RepScottPerry: The notion that I ever soug...
# 4   RT @bennyjohnson: MTG says EXACTLY what we're ...
# ..                                                ...
# 95  21. There is no amount of gun control laws tha...
# 96  20. feeling hopeless, spending hours in solitu...
# 97  19. School/Mass shooters who experienced child...
# 98  18. The left has attacked and eroded our cultu...
# 99  17. Fathers, grandfathers, and safe, good, god...
#
#                                          RepMGriffith  \
# 0   Under Joe Biden, the national average price fo...
# 1   Congressman Griffith's Weekly E-Newsletter 6.1...
# 2   The cost of living continues to soar. In May, ...
# 3   Summer shouldn’t mean blackouts, but there are...
# 4   High gas prices are putting a strain on everyt...
# ..                                                ...
# 95  President Biden’s policies are burdening Ameri...
# 96  On top of the record gas prices we’ve seen thi...
# 97  My statement on H.R. 6968, the Suspending Ener...
# 98  Another argument for American energy dominance...
# 99  This is a time for action on the world scene.\...
#
#                                       RepRaulGrijalva  \
# 0   RT @ksatnews: Group of Latino lawmakers demand...
# 1   RT @axios: Several Latino members of Congress ...
# 2   RT @RepRaulGrijalva: This #Pride Month, we’re ...
# 3   RT @JoaquinCastrotx: As authorities investigat...
# 4   This #GrijalvArt is from our #EJforAll Tour tr...
# ..                                                ...
# 95  In November, we have an opportunity to elect l...
# 96  No parent should be afraid to drop their child...
# 97  My heart breaks for the children, families, an...
# 98  RT @NPR: The U.S. operated or actively support...
# 99  Happy birthday and congrats to Christine Hirst...
#
#                                           RepGrothman  \
# 0   I always appreciate meeting with ABATE to disc...
# 1   Congratulations to Joseph Mikkelson of #Cedarb...
# 2   Enjoyed spending Memorial Day with #WI’s Hmong...
# 3   RT @GOPoversight: 🚨RIGHT NOW🚨\n\n@RepGrothman ...
# 4   Consumer prices rising 8.6 percent from last y...
# ..                                                ...
# 95  I had a wonderful time meeting the talented st...
# 96  The human trafficking operation run by cartels...
# 97  .@DHSgov reported 221,303 encounters last mont...
# 98  Shell Plastics does a remarkable job of supply...
# 99  Yesterday, I had the opportunity to visit Plym...
#
#                                       RepMichaelGuest  \
# 0   Haley and I join our state in prayer for the M...
# 1   A little over one year after Democrats took co...
# 2   RT @GOPLeader: The nationwide average price fo...
# 3   I am pleased by prospects for increased econom...
# 4   The Fentanyl crisis can only be addressed when...
# ..                                                ...
# 95  Inflation has increased every month of Joe Bid...
# 96  Obama’s Homeland Security Secretary said 4,000...
# 97  President Biden’s budget would provide million...
# 98  Gas prices have risen 81% since inauguration d...
# 99  Since President Biden took office, our border ...
#
#                                            RepGuthrie  \
# 0   My congressional staff &amp; interns recently ...
# 1   Inflation is at a new 4 decade high under the ...
# 2              Press release: https://t.co/sv9qWsKN7E
# 3   This bill would:\n\n➡️require FDA to immediate...
# 4   Parents in the United States should never have...
# ..                                                ...
# 95  RT @HouseCommerce: ICYMI → @cathymcmorris, @Re...
# 96  I visited with Ben, general manager of Colton’...
# 97  ICYMI: I joined @MorningsMaria on @FoxBusiness...
# 98  RT @HouseCommerce: 🚨 Must watch of @RepGuthrie...
# 99  Reminder that the “Facebook Favorite” contest ...
#
#                                         RepDebHaaland
# 0   I look forward to what the future holds and I’...
# 1   I love New Mexico. It's my home, where I raise...
# 2   I’m on the House Floor about to deliver my far...
# 3   I’ll be delivering my farewell remarks to the ...
# 4   It’s the honor of a lifetime to serve New Mexi...
# ..                                                ...
# 95  Have you seen today’s @GoogleDoodle? It’s cele...
# 96  My heart is with the loved ones of the 500,000...
# 97  Today marks the beginning of #EngineersWeek.\n...
# 98  On this day in 1965, Malcolm X was assassinate...
# 99  This past week, @POTUS &amp; @HouseDemocrats u...
#
# [100 rows x 196 columns]
